# %%
import os
print(os.getcwd())
# Out:
# C:\Users\silpa\OneDrive\Desktop\AIML

# %% [markdown]
# !pip install pandas

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\silpa\appdata\local\programs\python\python310\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\silpa\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\silpa\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\silpa\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\silpa\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\silpa\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data=pd.Series([10,23,43,65])
print(data)
# Out:
# 0    10
# 1    23
# 2    43
# 3    65
# dtype: int64

# %%
s=pd.DataFrame({'name':["Alice","Bob","John"],'age':[30,25,34],'score':[34,67,89]})
print(s)
# Out:
#     name  age  score
# 0  Alice   30     34
# 1    Bob   25     67
# 2   John   34     89

# %%
lst=[['Alice',25],['Bob',30]]
df=pd.DataFrame(lst,columns=['Name','Age'])

# %%
df.head()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.tail()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      object
#  1   Age     2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 160.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df['Name']
# Out:
# 0    Alice
# 1      Bob
# Name: Name, dtype: object

# %%
df[['Name','Age']]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.loc()

# %%
df.iloc()

# %%
df[df['Age']>25]
# Out:
#   Name  Age
# 1  Bob   30

# %%
df['Gender']=['F','M']
df.drop('Gender',axis=1, inplace=True)

# %%
df.isnull()
# Out:
#     Name    Age
# 0  False  False
# 1  False  False

# %%
df.dropna()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.fillna(0)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df['Age'] = [25, 30]
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.groupby('Name')['Age'].mean()
# Out:
# Name
# Alice    25.0
# Bob      30.0
# Name: Age, dtype: float64

# %%
df1 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie']
})
df2 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Marks': [85, 90, 78]
})
pd.merge(df1, df2, on='ID')
# Out:
#    ID     Name  Marks
# 0   1    Alice     85
# 1   2      Bob     90
# 2   3  Charlie     78

# %%
df1 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie']
})
df2 = pd.DataFrame({
    'Marks': [85, 90, 78]
})
df1.join(df2)
# Out:
#       Name  Marks
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     78

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\silpa\OneDrive\Desktop\AIML
# ['.ipynb_checkpoints', 'array.npy', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
import pandas as pd
data={
    'name':['Alice','Bob','Charlie'],
    'mark':[85,90,78]
}
df=pd.DataFrame(data)
df.to_csv('output.csv',index=False)
print("output.csv created")
# Out:
# output.csv created

# %%
import os
print(os.path.exists('output.csv'))
# Out:
# True

# %%
df=pd.read_csv('output.csv')
print(df)
# Out:
#       name  mark
# 0    Alice    85
# 1      Bob    90
# 2  Charlie    78

# %%
df.sort_values('mark')
# Out:
#       name  mark
# 2  Charlie    78
# 0    Alice    85
# 1      Bob    90

# %%
df['mark'].apply(lambda x: x+1)
# Out:
# 0    86
# 1    91
# 2    79
# Name: mark, dtype: int64

# %%
df['name'].unique()
# Out:
# array(['Alice', 'Bob', 'Charlie'], dtype=object)

# %%
df['mark'].value_counts()
# Out:
# mark
# 85    1
# 90    1
# 78    1
# Name: count, dtype: int64
